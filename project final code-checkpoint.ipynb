# %%
# necessary imports 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
df = pd.read_csv('Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# checking for null values

df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
values = df.Exited.value_counts()
labels = ['Not Exited', 'Exited']

fig, ax = plt.subplots(figsize = (4, 3), dpi = 100)
explode = (0, 0.09)

patches, texts, autotexts = ax.pie(values, labels = labels, autopct = '%1.2f%%', shadow = True,
                                   startangle = 90, explode = explode)

plt.setp(texts, color = 'grey')
plt.setp(autotexts, size = 8, color = 'white')
autotexts[1].set_color('black')
plt.show()

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# visualizing categorical variables
fig, ax = plt.subplots(3, 2, figsize=(18, 15))

sns.countplot(x='Geography', hue='Exited', data=df, ax=ax[0][0])
sns.countplot(x='Gender', hue='Exited', data=df, ax=ax[0][1])
sns.countplot(x='Tenure', hue='Exited', data=df, ax=ax[1][0])
sns.countplot(x='NumOfProducts', hue='Exited', data=df, ax=ax[1][1])
sns.countplot(x='HasCrCard', hue='Exited', data=df, ax=ax[2][0])
sns.countplot(x='IsActiveMember', hue='Exited', data=df, ax=ax[2][1])

plt.tight_layout()
plt.show()

# %%
# visualizing continuous variables

fig, ax = plt.subplots(2, 2, figsize = (16, 10))

sns.boxplot(x = 'Exited', y = 'CreditScore', data = df, ax = ax[0][0])
sns.boxplot(x = 'Exited', y = 'Age', data = df, ax = ax[0][1])
sns.boxplot(x = 'Exited', y = 'Balance', data = df, ax = ax[1][0])
sns.boxplot(x = 'Exited', y = 'EstimatedSalary', data = df, ax = ax[1][1])

plt.tight_layout()
plt.show()

# %%
# heatmap 

plt.figure(figsize = (20, 12))

corr = df.corr()

sns.heatmap(corr, linewidths = 1, annot = True, fmt = ".2f")
plt.show()

# %%
# dropping useless columns 

df.drop(columns = ['RowNumber', 'CustomerId', 'Surname'], axis = 1, inplace = True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.Geography.value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
# Encoding categorical variables

df['Geography'] = df['Geography'].map({'France' : 0, 'Germany' : 1, 'Spain' : 2})
df['Gender'] = df['Gender'].map({'Male' : 0, 'Female' : 1})

# %%
df.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       1   42       2       0.00              1
# 1          608          2       1   41       1   83807.86              1
# 2          502          0       1   42       8  159660.80              3
# 3          699          0       1   39       1       0.00              2
# 4          850          2       1   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# creating features and label 

from tensorflow.keras.utils import to_categorical

X = df.drop('Exited', axis = 1)
y = to_categorical(df.Exited)

# %%
# splitting data into training set and test set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
# Scaling data

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization

# initializing ann
model = Sequential()

# adding the first input layer and the first hidden layer
model.add(Dense(10, kernel_initializer = 'normal', activation = 'relu', input_shape = (10, )))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the third hidden layer
model.add(Dense(7, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the output layer
model.add(Dense(2, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set 

model_history = model.fit(X_train, y_train, validation_split = 0.20, validation_data = (X_test, y_test), epochs = 100)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 5s 9ms/step - loss: 0.6029 - accuracy: 0.7041 - val_loss: 0.5381 - val_accuracy: 0.8040
# Epoch 2/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4495 - accuracy: 0.8109 - val_loss: 0.4044 - val_accuracy: 0.8424
# Epoch 3/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3967 - accuracy: 0.8365 - val_loss: 0.3720 - val_accuracy: 0.8516
# Epoch 4/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3852 - accuracy: 0.8416 - val_loss: 0.3527 - val_accuracy: 0.8656
# Epoch 5/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3769 - accuracy: 0.8439 - val_loss: 0.3520 - val_accuracy: 0.8644
# Epoch 6/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3794 - accuracy: 0.8412 - val_loss: 0.3461 - val_accuracy: 0.8624
# Epoch 7/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3702 - accuracy: 0.8432 - val_loss: 0.3425 - val_accuracy: 0.8664
# Epoch 8/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3725 - accuracy: 0.8439 - val_loss: 0.3417 - val_accuracy: 0.8644
# Epoch 9/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3759 - accuracy: 0.8439 - val_loss: 0.3442 - val_accuracy: 0.8648
# Epoch 10/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3742 - accuracy: 0.8460 - val_loss: 0.3415 - val_accuracy: 0.8652
# Epoch 11/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3725 - accuracy: 0.8455 - val_loss: 0.3435 - val_accuracy: 0.8628
# Epoch 12/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3630 - accuracy: 0.8473 - val_loss: 0.3429 - val_accuracy: 0.8692
# Epoch 13/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3737 - accuracy: 0.8447 - val_loss: 0.3408 - val_accuracy: 0.8656
# Epoch 14/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3681 - accuracy: 0.8475 - val_loss: 0.3451 - val_accuracy: 0.8644
# Epoch 15/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3689 - accuracy: 0.8475 - val_loss: 0.3449 - val_accuracy: 0.8636
# Epoch 16/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3714 - accuracy: 0.8475 - val_loss: 0.3430 - val_accuracy: 0.8648
# Epoch 17/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3676 - accuracy: 0.8460 - val_loss: 0.3383 - val_accuracy: 0.8644
# Epoch 18/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3706 - accuracy: 0.8443 - val_loss: 0.3434 - val_accuracy: 0.8644
# Epoch 19/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3694 - accuracy: 0.8465 - val_loss: 0.3406 - val_accuracy: 0.8660
# Epoch 20/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3637 - accuracy: 0.8485 - val_loss: 0.3463 - val_accuracy: 0.8600
# Epoch 21/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3638 - accuracy: 0.8483 - val_loss: 0.3453 - val_accuracy: 0.8628
# Epoch 22/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3690 - accuracy: 0.8427 - val_loss: 0.3398 - val_accuracy: 0.8632
# Epoch 23/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3679 - accuracy: 0.8439 - val_loss: 0.3419 - val_accuracy: 0.8640
# Epoch 24/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3670 - accuracy: 0.8496 - val_loss: 0.3433 - val_accuracy: 0.8620
# Epoch 25/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3695 - accuracy: 0.8463 - val_loss: 0.3453 - val_accuracy: 0.8676
# Epoch 26/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3667 - accuracy: 0.8457 - val_loss: 0.3371 - val_accuracy: 0.8672
# Epoch 27/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3610 - accuracy: 0.8517 - val_loss: 0.3396 - val_accuracy: 0.8652
# Epoch 28/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3630 - accuracy: 0.8476 - val_loss: 0.3411 - val_accuracy: 0.8668
# Epoch 29/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3620 - accuracy: 0.8491 - val_loss: 0.3400 - val_accuracy: 0.8644
# Epoch 30/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3669 - accuracy: 0.8480 - val_loss: 0.3423 - val_accuracy: 0.8624
# Epoch 31/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3655 - accuracy: 0.8459 - val_loss: 0.3401 - val_accuracy: 0.8656
# Epoch 32/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3651 - accuracy: 0.8473 - val_loss: 0.3471 - val_accuracy: 0.8628
# Epoch 33/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3659 - accuracy: 0.8469 - val_loss: 0.3399 - val_accuracy: 0.8664
# Epoch 34/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3606 - accuracy: 0.8485 - val_loss: 0.3413 - val_accuracy: 0.8640
# Epoch 35/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3634 - accuracy: 0.8479 - val_loss: 0.3417 - val_accuracy: 0.8668
# Epoch 36/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3604 - accuracy: 0.8501 - val_loss: 0.3421 - val_accuracy: 0.8684
# Epoch 37/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3650 - accuracy: 0.8453 - val_loss: 0.3394 - val_accuracy: 0.8644
# Epoch 38/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3567 - accuracy: 0.8467 - val_loss: 0.3370 - val_accuracy: 0.8680
# Epoch 39/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3642 - accuracy: 0.8469 - val_loss: 0.3423 - val_accuracy: 0.8628
# Epoch 40/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3641 - accuracy: 0.8459 - val_loss: 0.3402 - val_accuracy: 0.8636
# Epoch 41/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3623 - accuracy: 0.8477 - val_loss: 0.3368 - val_accuracy: 0.8660
# Epoch 42/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3632 - accuracy: 0.8459 - val_loss: 0.3357 - val_accuracy: 0.8720
# Epoch 43/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3620 - accuracy: 0.8460 - val_loss: 0.3426 - val_accuracy: 0.8684
# Epoch 44/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3619 - accuracy: 0.8477 - val_loss: 0.3420 - val_accuracy: 0.8636
# Epoch 45/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3619 - accuracy: 0.8489 - val_loss: 0.3381 - val_accuracy: 0.8656
# Epoch 46/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3677 - accuracy: 0.8448 - val_loss: 0.3403 - val_accuracy: 0.8652
# Epoch 47/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3591 - accuracy: 0.8476 - val_loss: 0.3408 - val_accuracy: 0.8652
# Epoch 48/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3613 - accuracy: 0.8440 - val_loss: 0.3414 - val_accuracy: 0.8624
# Epoch 49/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3609 - accuracy: 0.8495 - val_loss: 0.3404 - val_accuracy: 0.8696
# Epoch 50/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3629 - accuracy: 0.8473 - val_loss: 0.3409 - val_accuracy: 0.8644
# Epoch 51/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3646 - accuracy: 0.8457 - val_loss: 0.3446 - val_accuracy: 0.8624
# Epoch 52/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3639 - accuracy: 0.8460 - val_loss: 0.3417 - val_accuracy: 0.8664
# Epoch 53/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3624 - accuracy: 0.8477 - val_loss: 0.3386 - val_accuracy: 0.8684
# Epoch 54/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3611 - accuracy: 0.8480 - val_loss: 0.3462 - val_accuracy: 0.8616
# Epoch 55/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3654 - accuracy: 0.8463 - val_loss: 0.3402 - val_accuracy: 0.8660
# Epoch 56/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3543 - accuracy: 0.8540 - val_loss: 0.3435 - val_accuracy: 0.8648
# Epoch 57/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3582 - accuracy: 0.8480 - val_loss: 0.3443 - val_accuracy: 0.8664
# Epoch 58/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3596 - accuracy: 0.8492 - val_loss: 0.3427 - val_accuracy: 0.8644
# Epoch 59/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3624 - accuracy: 0.8456 - val_loss: 0.3382 - val_accuracy: 0.8656
# Epoch 60/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3635 - accuracy: 0.8471 - val_loss: 0.3401 - val_accuracy: 0.8656
# Epoch 61/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3601 - accuracy: 0.8508 - val_loss: 0.3368 - val_accuracy: 0.8672
# Epoch 62/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3617 - accuracy: 0.8499 - val_loss: 0.3351 - val_accuracy: 0.8672
# Epoch 63/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3596 - accuracy: 0.8501 - val_loss: 0.3406 - val_accuracy: 0.8668
# Epoch 64/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3624 - accuracy: 0.8492 - val_loss: 0.3379 - val_accuracy: 0.8660
# Epoch 65/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3588 - accuracy: 0.8499 - val_loss: 0.3392 - val_accuracy: 0.8676
# Epoch 66/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3615 - accuracy: 0.8460 - val_loss: 0.3417 - val_accuracy: 0.8664
# Epoch 67/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3569 - accuracy: 0.8492 - val_loss: 0.3400 - val_accuracy: 0.8664
# Epoch 68/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3575 - accuracy: 0.8527 - val_loss: 0.3419 - val_accuracy: 0.8644
# Epoch 69/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3643 - accuracy: 0.8427 - val_loss: 0.3419 - val_accuracy: 0.8648
# Epoch 70/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3601 - accuracy: 0.8489 - val_loss: 0.3407 - val_accuracy: 0.8652
# Epoch 71/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3589 - accuracy: 0.8481 - val_loss: 0.3426 - val_accuracy: 0.8684
# Epoch 72/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3566 - accuracy: 0.8515 - val_loss: 0.3381 - val_accuracy: 0.8668
# Epoch 73/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3567 - accuracy: 0.8497 - val_loss: 0.3388 - val_accuracy: 0.8696
# Epoch 74/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3595 - accuracy: 0.8507 - val_loss: 0.3394 - val_accuracy: 0.8652
# Epoch 75/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3574 - accuracy: 0.8500 - val_loss: 0.3386 - val_accuracy: 0.8680
# Epoch 76/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3553 - accuracy: 0.8519 - val_loss: 0.3384 - val_accuracy: 0.8656
# Epoch 77/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3634 - accuracy: 0.8465 - val_loss: 0.3423 - val_accuracy: 0.8636
# Epoch 78/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3606 - accuracy: 0.8483 - val_loss: 0.3391 - val_accuracy: 0.8680
# Epoch 79/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3594 - accuracy: 0.8488 - val_loss: 0.3422 - val_accuracy: 0.8684
# Epoch 80/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3566 - accuracy: 0.8484 - val_loss: 0.3399 - val_accuracy: 0.8680
# Epoch 81/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3629 - accuracy: 0.8432 - val_loss: 0.3425 - val_accuracy: 0.8672
# Epoch 82/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3594 - accuracy: 0.8503 - val_loss: 0.3390 - val_accuracy: 0.8636
# Epoch 83/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3591 - accuracy: 0.8511 - val_loss: 0.3395 - val_accuracy: 0.8636
# Epoch 84/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3581 - accuracy: 0.8485 - val_loss: 0.3406 - val_accuracy: 0.8652
# Epoch 85/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3648 - accuracy: 0.8496 - val_loss: 0.3398 - val_accuracy: 0.8644
# Epoch 86/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3603 - accuracy: 0.8492 - val_loss: 0.3407 - val_accuracy: 0.8668
# Epoch 87/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3589 - accuracy: 0.8517 - val_loss: 0.3368 - val_accuracy: 0.8660
# Epoch 88/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3587 - accuracy: 0.8529 - val_loss: 0.3363 - val_accuracy: 0.8660
# Epoch 89/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3587 - accuracy: 0.8485 - val_loss: 0.3410 - val_accuracy: 0.8616
# Epoch 90/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3621 - accuracy: 0.8487 - val_loss: 0.3415 - val_accuracy: 0.8672
# Epoch 91/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3629 - accuracy: 0.8501 - val_loss: 0.3429 - val_accuracy: 0.8604
# Epoch 92/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3556 - accuracy: 0.8519 - val_loss: 0.3425 - val_accuracy: 0.8632
# Epoch 93/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3628 - accuracy: 0.8492 - val_loss: 0.3416 - val_accuracy: 0.8620
# Epoch 94/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3598 - accuracy: 0.8512 - val_loss: 0.3401 - val_accuracy: 0.8624
# Epoch 95/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3570 - accuracy: 0.8535 - val_loss: 0.3445 - val_accuracy: 0.8636
# Epoch 96/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3614 - accuracy: 0.8503 - val_loss: 0.3432 - val_accuracy: 0.8632
# Epoch 97/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3574 - accuracy: 0.8479 - val_loss: 0.3431 - val_accuracy: 0.8664
# Epoch 98/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3584 - accuracy: 0.8499 - val_loss: 0.3427 - val_accuracy: 0.8636
# Epoch 99/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3584 - accuracy: 0.8509 - val_loss: 0.3373 - val_accuracy: 0.8664
# Epoch 100/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3543 - accuracy: 0.8509 - val_loss: 0.3418 - val_accuracy: 0.8640

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))

train_loss = model_history.history['loss']
val_loss = model_history.history['val_loss'] 
epochs = range(1, len(train_loss) + 1)

sns.lineplot(x=epochs, y=train_loss, label='Training Loss')
sns.lineplot(x=epochs, y=val_loss, label='Validation Loss')
plt.title('Training and Validation Loss\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))

train_accuracy = model_history.history['accuracy']
val_accuracy = model_history.history['val_accuracy'] 
epochs = range(1, len(train_accuracy) + 1)

sns.lineplot(x=epochs, y=train_accuracy, label='Training Accuracy')
sns.lineplot(x=epochs, y=val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
acc = model.evaluate(X_test, y_test)[1]

print(f'Accuracy of model is {acc}')
# Out:
# 79/79 [==============================] - 0s 4ms/step - loss: 0.3418 - accuracy: 0.8640
# Accuracy of model is 0.8640000224113464

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                110
#
#  dropout (Dropout)           (None, 10)                0
#
#  batch_normalization (Batch  (None, 10)                40
#  Normalization)
#
#  dense_1 (Dense)             (None, 7)                 77
#
#  dropout_1 (Dropout)         (None, 7)                 0
#
#  batch_normalization_1 (Bat  (None, 7)                 28
#  chNormalization)
#
#  dense_2 (Dense)             (None, 2)                 16
#
# =================================================================
# Total params: 271 (1.06 KB)
# Trainable params: 237 (948.00 Byte)
# Non-trainable params: 34 (136.00 Byte)
# _________________________________________________________________

# %%
model = Sequential()

# adding the first input layer and the first hidden layer
model.add(Dense(10, kernel_initializer = 'normal', activation = 'relu', input_shape = (10, )))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.6))
model.add(BatchNormalization())

# adding the third hidden layer
model.add(Dense(7, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.6))
model.add(BatchNormalization())

# adding the output layer
model.add(Dense(2, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set 

model_history = model.fit(X_train, y_train, validation_split = 0.20, validation_data = (X_test, y_test), epochs = 100)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 5s 8ms/step - loss: 0.6437 - accuracy: 0.7223 - val_loss: 0.5762 - val_accuracy: 0.8040
# Epoch 2/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5175 - accuracy: 0.7816 - val_loss: 0.4573 - val_accuracy: 0.8040
# Epoch 3/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4802 - accuracy: 0.7892 - val_loss: 0.4387 - val_accuracy: 0.8040
# Epoch 4/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4704 - accuracy: 0.7936 - val_loss: 0.4330 - val_accuracy: 0.8044
# Epoch 5/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4695 - accuracy: 0.7944 - val_loss: 0.4291 - val_accuracy: 0.8052
# Epoch 6/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4652 - accuracy: 0.8000 - val_loss: 0.4246 - val_accuracy: 0.8104
# Epoch 7/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4633 - accuracy: 0.7939 - val_loss: 0.4264 - val_accuracy: 0.8052
# Epoch 8/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4602 - accuracy: 0.7997 - val_loss: 0.4224 - val_accuracy: 0.8148
# Epoch 9/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4605 - accuracy: 0.8007 - val_loss: 0.4198 - val_accuracy: 0.8168
# Epoch 10/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4646 - accuracy: 0.8005 - val_loss: 0.4233 - val_accuracy: 0.8212
# Epoch 11/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4564 - accuracy: 0.8025 - val_loss: 0.4119 - val_accuracy: 0.8264
# Epoch 12/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4597 - accuracy: 0.7987 - val_loss: 0.4129 - val_accuracy: 0.8248
# Epoch 13/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4586 - accuracy: 0.8033 - val_loss: 0.4121 - val_accuracy: 0.8272
# Epoch 14/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4550 - accuracy: 0.8020 - val_loss: 0.4096 - val_accuracy: 0.8224
# Epoch 15/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4579 - accuracy: 0.8007 - val_loss: 0.3947 - val_accuracy: 0.8380
# Epoch 16/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4518 - accuracy: 0.8081 - val_loss: 0.3970 - val_accuracy: 0.8404
# Epoch 17/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4559 - accuracy: 0.8024 - val_loss: 0.3944 - val_accuracy: 0.8396
# Epoch 18/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4544 - accuracy: 0.8072 - val_loss: 0.3977 - val_accuracy: 0.8444
# Epoch 19/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4477 - accuracy: 0.8101 - val_loss: 0.3899 - val_accuracy: 0.8428
# Epoch 20/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4506 - accuracy: 0.8100 - val_loss: 0.3916 - val_accuracy: 0.8396
# Epoch 21/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4566 - accuracy: 0.8073 - val_loss: 0.3980 - val_accuracy: 0.8316
# Epoch 22/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4524 - accuracy: 0.8099 - val_loss: 0.3941 - val_accuracy: 0.8388
# Epoch 23/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4510 - accuracy: 0.8083 - val_loss: 0.3923 - val_accuracy: 0.8368
# Epoch 24/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4512 - accuracy: 0.8069 - val_loss: 0.3833 - val_accuracy: 0.8496
# Epoch 25/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4542 - accuracy: 0.8099 - val_loss: 0.3893 - val_accuracy: 0.8388
# Epoch 26/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4533 - accuracy: 0.8125 - val_loss: 0.3957 - val_accuracy: 0.8332
# Epoch 27/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4544 - accuracy: 0.8083 - val_loss: 0.3862 - val_accuracy: 0.8472
# Epoch 28/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4511 - accuracy: 0.8123 - val_loss: 0.3886 - val_accuracy: 0.8452
# Epoch 29/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4514 - accuracy: 0.8099 - val_loss: 0.3891 - val_accuracy: 0.8404
# Epoch 30/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4485 - accuracy: 0.8093 - val_loss: 0.3907 - val_accuracy: 0.8392
# Epoch 31/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4597 - accuracy: 0.8060 - val_loss: 0.4061 - val_accuracy: 0.8268
# Epoch 32/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4559 - accuracy: 0.8065 - val_loss: 0.3927 - val_accuracy: 0.8416
# Epoch 33/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4507 - accuracy: 0.8041 - val_loss: 0.3904 - val_accuracy: 0.8452
# Epoch 34/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4541 - accuracy: 0.8079 - val_loss: 0.3972 - val_accuracy: 0.8360
# Epoch 35/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4557 - accuracy: 0.8071 - val_loss: 0.3943 - val_accuracy: 0.8368
# Epoch 36/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4558 - accuracy: 0.8108 - val_loss: 0.3844 - val_accuracy: 0.8508
# Epoch 37/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4578 - accuracy: 0.8104 - val_loss: 0.3963 - val_accuracy: 0.8380
# Epoch 38/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4536 - accuracy: 0.8113 - val_loss: 0.3973 - val_accuracy: 0.8368
# Epoch 39/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4488 - accuracy: 0.8141 - val_loss: 0.3912 - val_accuracy: 0.8444
# Epoch 40/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.4515 - accuracy: 0.8137 - val_loss: 0.3924 - val_accuracy: 0.8412
# Epoch 41/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.4505 - accuracy: 0.8101 - val_loss: 0.3907 - val_accuracy: 0.8420
# Epoch 42/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4565 - accuracy: 0.8093 - val_loss: 0.3935 - val_accuracy: 0.8380
# Epoch 43/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4551 - accuracy: 0.8095 - val_loss: 0.4030 - val_accuracy: 0.8372
# Epoch 44/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4527 - accuracy: 0.8107 - val_loss: 0.3929 - val_accuracy: 0.8444
# Epoch 45/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4496 - accuracy: 0.8107 - val_loss: 0.3897 - val_accuracy: 0.8436
# Epoch 46/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4490 - accuracy: 0.8125 - val_loss: 0.3950 - val_accuracy: 0.8376
# Epoch 47/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4438 - accuracy: 0.8144 - val_loss: 0.3856 - val_accuracy: 0.8452
# Epoch 48/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4531 - accuracy: 0.8095 - val_loss: 0.3839 - val_accuracy: 0.8456
# Epoch 49/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4550 - accuracy: 0.8073 - val_loss: 0.3883 - val_accuracy: 0.8420
# Epoch 50/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4490 - accuracy: 0.8100 - val_loss: 0.3837 - val_accuracy: 0.8440
# Epoch 51/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4520 - accuracy: 0.8121 - val_loss: 0.3833 - val_accuracy: 0.8516
# Epoch 52/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4524 - accuracy: 0.8099 - val_loss: 0.3893 - val_accuracy: 0.8448
# Epoch 53/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4522 - accuracy: 0.8113 - val_loss: 0.3894 - val_accuracy: 0.8428
# Epoch 54/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4535 - accuracy: 0.8097 - val_loss: 0.3913 - val_accuracy: 0.8432
# Epoch 55/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.4518 - accuracy: 0.8096 - val_loss: 0.3959 - val_accuracy: 0.8372
# Epoch 56/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4540 - accuracy: 0.8139 - val_loss: 0.3929 - val_accuracy: 0.8460
# Epoch 57/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4492 - accuracy: 0.8135 - val_loss: 0.3919 - val_accuracy: 0.8396
# Epoch 58/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4521 - accuracy: 0.8125 - val_loss: 0.3890 - val_accuracy: 0.8460
# Epoch 59/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4543 - accuracy: 0.8123 - val_loss: 0.3893 - val_accuracy: 0.8432
# Epoch 60/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4538 - accuracy: 0.8113 - val_loss: 0.3888 - val_accuracy: 0.8476
# Epoch 61/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4600 - accuracy: 0.8089 - val_loss: 0.3942 - val_accuracy: 0.8388
# Epoch 62/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4510 - accuracy: 0.8100 - val_loss: 0.3921 - val_accuracy: 0.8412
# Epoch 63/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4547 - accuracy: 0.8091 - val_loss: 0.3940 - val_accuracy: 0.8424
# Epoch 64/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4481 - accuracy: 0.8103 - val_loss: 0.3868 - val_accuracy: 0.8484
# Epoch 65/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4530 - accuracy: 0.8109 - val_loss: 0.3922 - val_accuracy: 0.8408
# Epoch 66/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4544 - accuracy: 0.8107 - val_loss: 0.3922 - val_accuracy: 0.8440
# Epoch 67/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4543 - accuracy: 0.8079 - val_loss: 0.3893 - val_accuracy: 0.8420
# Epoch 68/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4505 - accuracy: 0.8103 - val_loss: 0.3841 - val_accuracy: 0.8500
# Epoch 69/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4482 - accuracy: 0.8132 - val_loss: 0.3908 - val_accuracy: 0.8408
# Epoch 70/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4494 - accuracy: 0.8113 - val_loss: 0.3902 - val_accuracy: 0.8404
# Epoch 71/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4462 - accuracy: 0.8097 - val_loss: 0.3946 - val_accuracy: 0.8352
# Epoch 72/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4483 - accuracy: 0.8120 - val_loss: 0.3868 - val_accuracy: 0.8456
# Epoch 73/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4449 - accuracy: 0.8156 - val_loss: 0.3924 - val_accuracy: 0.8380
# Epoch 74/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4518 - accuracy: 0.8077 - val_loss: 0.3929 - val_accuracy: 0.8384
# Epoch 75/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4524 - accuracy: 0.8096 - val_loss: 0.3884 - val_accuracy: 0.8444
# Epoch 76/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4495 - accuracy: 0.8111 - val_loss: 0.3876 - val_accuracy: 0.8436
# Epoch 77/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4562 - accuracy: 0.8077 - val_loss: 0.3911 - val_accuracy: 0.8456
# Epoch 78/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4489 - accuracy: 0.8133 - val_loss: 0.3871 - val_accuracy: 0.8408
# Epoch 79/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4564 - accuracy: 0.8084 - val_loss: 0.3876 - val_accuracy: 0.8436
# Epoch 80/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4483 - accuracy: 0.8117 - val_loss: 0.3833 - val_accuracy: 0.8468
# Epoch 81/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4521 - accuracy: 0.8096 - val_loss: 0.3857 - val_accuracy: 0.8448
# Epoch 82/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4531 - accuracy: 0.8097 - val_loss: 0.3916 - val_accuracy: 0.8416
# Epoch 83/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4511 - accuracy: 0.8091 - val_loss: 0.3946 - val_accuracy: 0.8344
# Epoch 84/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4480 - accuracy: 0.8128 - val_loss: 0.3952 - val_accuracy: 0.8328
# Epoch 85/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4553 - accuracy: 0.8128 - val_loss: 0.3939 - val_accuracy: 0.8392
# Epoch 86/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4592 - accuracy: 0.8099 - val_loss: 0.3880 - val_accuracy: 0.8484
# Epoch 87/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4496 - accuracy: 0.8137 - val_loss: 0.3861 - val_accuracy: 0.8460
# Epoch 88/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4532 - accuracy: 0.8107 - val_loss: 0.3935 - val_accuracy: 0.8376
# Epoch 89/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4478 - accuracy: 0.8139 - val_loss: 0.3909 - val_accuracy: 0.8376
# Epoch 90/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4529 - accuracy: 0.8136 - val_loss: 0.3898 - val_accuracy: 0.8424
# Epoch 91/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4527 - accuracy: 0.8128 - val_loss: 0.3960 - val_accuracy: 0.8380
# Epoch 92/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4586 - accuracy: 0.8140 - val_loss: 0.3957 - val_accuracy: 0.8388
# Epoch 93/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4543 - accuracy: 0.8107 - val_loss: 0.3830 - val_accuracy: 0.8520
# Epoch 94/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4539 - accuracy: 0.8115 - val_loss: 0.3956 - val_accuracy: 0.8360
# Epoch 95/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4472 - accuracy: 0.8133 - val_loss: 0.3888 - val_accuracy: 0.8396
# Epoch 96/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4522 - accuracy: 0.8097 - val_loss: 0.3912 - val_accuracy: 0.8380
# Epoch 97/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4494 - accuracy: 0.8120 - val_loss: 0.3856 - val_accuracy: 0.8468
# Epoch 98/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4556 - accuracy: 0.8087 - val_loss: 0.3864 - val_accuracy: 0.8452
# Epoch 99/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.4515 - accuracy: 0.8099 - val_loss: 0.3883 - val_accuracy: 0.8468
# Epoch 100/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4465 - accuracy: 0.8151 - val_loss: 0.3838 - val_accuracy: 0.8496

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(12, 6))

train_loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(1, len(train_loss) + 1)

sns.lineplot(x=np.array(epochs), y=np.array(train_loss), label='Training Loss')
sns.lineplot(x=np.array(epochs), y=np.array(val_loss), label='Validation Loss')
plt.title('Training and Validation Loss\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(12, 6))

train_accuracy = model_history.history['accuracy']
val_accuracy = model_history.history['val_accuracy']
epochs = range(1, len(train_accuracy) + 1)

# Create a DataFrame to use with sns.lineplot
data = pd.DataFrame({'Epochs': epochs, 'Training Accuracy': train_accuracy, 'Validation Accuracy': val_accuracy})

sns.lineplot(x='Epochs', y='Training Accuracy', data=data, label='Training Accuracy')
sns.lineplot(x='Epochs', y='Validation Accuracy', data=data, label='Validation Accuracy')
plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
acc = model.evaluate(X_test, y_test)[1]

print(f'Accuracy of model is {acc}')
# Out:
# 79/79 [==============================] - 0s 3ms/step - loss: 0.3838 - accuracy: 0.8496
# Accuracy of model is 0.8496000170707703

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                110
#
#  dropout_2 (Dropout)         (None, 10)                0
#
#  batch_normalization_2 (Bat  (None, 10)                40
#  chNormalization)
#
#  dense_4 (Dense)             (None, 7)                 77
#
#  dropout_3 (Dropout)         (None, 7)                 0
#
#  batch_normalization_3 (Bat  (None, 7)                 28
#  chNormalization)
#
#  dense_5 (Dense)             (None, 2)                 16
#
# =================================================================
# Total params: 271 (1.06 KB)
# Trainable params: 237 (948.00 Byte)
# Non-trainable params: 34 (136.00 Byte)
# _________________________________________________________________
